# %% [markdown]
# # Web Scraping and Parsing Inhibitor Data in Python
#
# KIDFamMap is a database listing thousands of known kinase inhibitors.
#
# Kinases are listed on the web page at URL http://gemdock.life.nctu.edu.tw/kidfammap/browse.php and each can be clicked on individually to navigate to a page of information about that kinase. This page includes a link to another page, which contains a table of inhibitors for that kinase.
#
# Here we use the scrapy package to create and run a spider to scrape the website's HTML code for all of the relevant information.
# - First, the URLs for each kinase's web page are obtained from the main page.
# - These URLs are then followed, taking us to each kinase's web page.
# - From there we extract the URLs for the web page containing the individual kinase's table of inhibitors.
# - We then follow these URLs and extract all of the relevant information.
#
# Once the data has been extracted from the website, it is cleaned and inserted into a Pandas data frame.
#
# After that, the following steps take place:
# - Using information in the data frame, we generate a column of URLs that our web app can use to display images of the inhibitors' chemical structures.
# - Make kinases and inhibitors uppercase.
# - Translate kinase names to match "Entry name" in kinase table
# - Remove duplicate rows.
# - Remove unnecessary columns.
# - Use this data frame to make two data frames: one listing the kinase-inhibitor pairs, and one listing each inhibitor alongside all of its information. These two data sets can then be linked via the inhibitor name in our relational database.
# - Make primary key columns.
# - Export as csv files.
#
# Template code and general information about scrapy was gained from https://www.datacamp.com/courses/web-scraping-with-python

# %% [markdown]
# Import packages

# %%
import pandas as pd
import scrapy
from scrapy.crawler import CrawlerProcess
import urllib.parse 
import urllib.request

# %% [markdown]
# Make a spider

# %%
# Use the scrapy.Spider class to make your own spider

class InhibitorSpider( scrapy.Spider ):
    
    name = "inhibitor_spider"
    
    # Define the first action to take
        
    def start_requests( self ): 
        
        # Define which URL to start at
        
        url = 'http://gemdock.life.nctu.edu.tw/kidfammap/browse.php'

        # Go to the website at the above URL and get a response object
        # Define what to do with the response object
        # i.e. send it to the parse method defined below
        
        yield scrapy.Request( url = url, callback = self.parse )
            
    # Using the previous response object, get the URLs for each 
    # kinase's web page, and go to those websites  
    
    def parse( self, response ):
        
        # Each kinase listed on the page is a hyperlink, leading to
        # a page of information for that kinase.
        # Define a CSS locator to point to the URLs in those
        # hyperlinks and extract them as strings.
        
        links = response.css('table > tr > td > a::attr(href)').extract()
        
        # Go to the kinases' web pages using the new URLs
        # and send the response objects to the parse2 method below
        
        for link in links:
            yield response.follow(url = link, callback = self.parse2)
    
    # Using the previous response objects, get the URLs for each 
    # inhibitor table.
    
    def parse2( self, response ):
        
        # Each kinase's web page has a hyperlink to another page 
        # containing a table of inhibitors for that kinase.
        # Define a CSS locator to point to the URLs in those
        # hyperlinks and extract them as strings.
        
        inhib_links = response.css('a.show_inhibitor::attr(href)').extract()
        
        # Go to the kinases' web pages using the new URLs
        # and send the response objects to the parse3 method below
        
        for ilink in inhib_links:
            yield response.follow(url = ilink, callback = self.parse3)

    # Using the previous response objects, get information from the 
    # table of inhibitors for each kinase
    
    def parse3( self, response ):
        
        # Each inhibitor list web page has information we'd like to
        # extract and place into a list "inhibs" (which we must initialise
        # in the next cell rather than here).
        # Define a CSS locator to point to the data in the rows
        # of the inhibitor table and extract the text.
       
        raw = response.css('div.result tbody > tr').extract()
        
        # Save the data in a list "fields"
        
        fields = [field for field in raw]
        
        # For each kinase, append the information about its
        # inhibitors to "inhibs"
        
        inhibs.append(fields)

# %% [markdown]
# Run the spider: crawl KIDFamMap for inhibitors

# %%
# Our data will be returned to "inhibs"

inhibs = [] 

# Run the spider

process = CrawlerProcess()
process.crawl(InhibitorSpider)
process.start()

# N.B. kernel needs to be cleared before repeating
# Out:
# 2020-01-15 19:21:41 [scrapy.utils.log] INFO: Scrapy 1.8.0 started (bot: scrapybot)
# 2020-01-15 19:21:41 [scrapy.utils.log] INFO: Versions: lxml 4.4.1.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 19.10.0, Python 3.7.4 (default, Aug  9 2019, 18:34:13) [MSC v.1915 64 bit (AMD64)], pyOpenSSL 19.0.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.7, Platform Windows-10-10.0.18362-SP0
# 2020-01-15 19:21:41 [scrapy.crawler] INFO: Overridden settings: {}
# 2020-01-15 19:21:41 [scrapy.extensions.telnet] INFO: Telnet Password: 0c32db61d08fe7b4
# 2020-01-15 19:21:41 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2020-01-15 19:21:42 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-01-15 19:21:42 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-01-15 19:21:42 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2020-01-15 19:21:42 [scrapy.core.engine] INFO: Spider opened
# 2020-01-15 19:21:42 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-01-15 19:21:42 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-01-15 19:21:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/browse.php> (referer: None)
# 2020-01-15 19:21:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=ADRBK1> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=DAPK3> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=DAPK2> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=DAPK1> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MAPKAPK3> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MYLK4> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MKNK2> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=PASK> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MAPKAPK2> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=PIM1> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=ZAK> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CASK> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CAMK4> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CAMK2G> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CHEK1> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=ADRBK1&Query_Pid=ADRBK1&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=ADRBK1)
# 2020-01-15 19:21:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=DAPK3&Query_Pid=DAPK3&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=DAPK3)
# 2020-01-15 19:21:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=DAPK2&Query_Pid=DAPK2&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=DAPK2)
# 2020-01-15 19:21:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=DAPK1&Query_Pid=DAPK1&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=DAPK1)
# 2020-01-15 19:21:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=TGFBR2> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MAP3K13> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MAP3K12> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=PASK&Query_Pid=PASK&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=PASK)
# 2020-01-15 19:21:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=MKNK2&Query_Pid=MKNK2&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MKNK2)
# 2020-01-15 19:21:47 [scrapy.dupefilters] DEBUG: Filtered duplicate request: <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=MAP3K9&Query_Pid=MAP3K9&Query_Cid=&Query_Family=> - no more duplicates will be shown (see DUPEFILTER_DEBUG to show all duplicates)
# 2020-01-15 19:21:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=MYLK4&Query_Pid=MYLK4&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MYLK4)
# 2020-01-15 19:21:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=MAPKAPK3&Query_Pid=MAPKAPK3&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MAPKAPK3)
# 2020-01-15 19:21:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MAP3K11> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=CAMK2G&Query_Pid=CAMK2G&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CAMK2G)
# 2020-01-15 19:21:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=CAMK4&Query_Pid=CAMK4&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CAMK4)
# 2020-01-15 19:21:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=CASK&Query_Pid=CASK&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CASK)
# 2020-01-15 19:21:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=MAP3K9&Query_Pid=MAP3K9&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=ZAK)
# 2020-01-15 19:21:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=MAPKAPK2&Query_Pid=MAPKAPK2&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MAPKAPK2)
# 2020-01-15 19:21:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=PIM2> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=ACVR2A&Query_Pid=ACVR2A&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=TGFBR2)
# 2020-01-15 19:21:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MAP3K10> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=KSR1> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=PIM1&Query_Pid=PIM1&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=PIM1)
# 2020-01-15 19:21:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=KIAA1804> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=BMPR1A> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=ARAF> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=AMHR2> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=ACVR1C> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=ACVR1B> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=YES1> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=TYRO3> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CHEK2> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=TXK> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=TNK1> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=CHEK1&Query_Pid=CHEK1&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CHEK1)
# 2020-01-15 19:21:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=TIE1> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=PIM2&Query_Pid=PIM2&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=PIM2)
# 2020-01-15 19:21:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=TEC> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=SRMS> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=BMPR1B&Query_Pid=BMPR1B&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=BMPR1A)
# 2020-01-15 19:21:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=KSR2&Query_Pid=KSR2&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=KSR1)
# 2020-01-15 19:21:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=IRAK1> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=RYK> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=ROS1> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=STYK1> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=ROR2> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=ROR1> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=TNK2&Query_Pid=TNK2&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=TNK1)
# 2020-01-15 19:21:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=MERTK&Query_Pid=MERTK&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=TYRO3)
# 2020-01-15 19:21:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=CHEK2&Query_Pid=CHEK2&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CHEK2)
# 2020-01-15 19:21:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=TEK&Query_Pid=TEK&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=TIE1)
# 2020-01-15 19:21:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=PTK6> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=RAF1&Query_Pid=RAF1&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=ARAF)
# 2020-01-15 19:21:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=PTK7> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=ITK&Query_Pid=ITK&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=TXK)
# 2020-01-15 19:21:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=BMPR2&Query_Pid=BMPR2&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=AMHR2)
# 2020-01-15 19:21:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=TGFBR1&Query_Pid=TGFBR1&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=ACVR1C)
# 2020-01-15 19:21:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=FYN&Query_Pid=FYN&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=SRMS)
# 2020-01-15 19:21:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=IRAK4&Query_Pid=IRAK4&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=IRAK1)
# 2020-01-15 19:21:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=SRC&Query_Pid=SRC&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=YES1)
# 2020-01-15 19:21:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=MET&Query_Pid=MET&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=RYK)
# 2020-01-15 19:21:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=NTRK3> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=PDGFRB> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=PDGFRA> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=NTRK2> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=NTRK1> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=ALK&Query_Pid=ALK&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=ROS1)
# 2020-01-15 19:21:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MUSK> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MATK> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=LMTK3> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=LTK> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=INSRR> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=INSR&Query_Pid=INSR&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=ROR2)
# 2020-01-15 19:21:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=FGR> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=FGFR4> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=FGFR3> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=FLT4> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=FRK> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=FER> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=EPHB6> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=FGFR1&Query_Pid=FGFR1&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=STYK1)
# 2020-01-15 19:21:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=EPHB3> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=IGF1R&Query_Pid=IGF1R&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=ROR1)
# 2020-01-15 19:21:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=EPHB2> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=EPHB1> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=EPHA10> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=DDR2> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=DDR1> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=FGFR2&Query_Pid=FGFR2&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=FGFR4)
# 2020-01-15 19:21:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=BMX> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=BLK> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=EPHA1> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=AXL> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=AATK> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=KIT&Query_Pid=KIT&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=PDGFRB)
# 2020-01-15 19:21:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=CSK&Query_Pid=CSK&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MATK)
# 2020-01-15 19:21:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=STK39> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=PAK3> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=PAK2> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=FES&Query_Pid=FES&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=FER)
# 2020-01-15 19:21:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=LYN&Query_Pid=LYN&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=FRK)
# 2020-01-15 19:21:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=EPHA7&Query_Pid=EPHA7&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=EPHA10)
# 2020-01-15 19:21:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=NRK> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MYO3B> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MYO3A> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MINK1> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MAP4K5> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MAP4K4> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=EPHA3&Query_Pid=EPHA3&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=EPHA1)
# 2020-01-15 19:21:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MAP4K3> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=EPHB4&Query_Pid=EPHB4&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=EPHB6)
# 2020-01-15 19:21:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=BTK&Query_Pid=BTK&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=BMX)
# 2020-01-15 19:21:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MAP2K5> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MAP2K3> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=ALS2CR2> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=PAK1&Query_Pid=PAK1&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=PAK3)
# 2020-01-15 19:21:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=HCK&Query_Pid=HCK&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=BLK)
# 2020-01-15 19:21:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=OXSR1&Query_Pid=OXSR1&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=STK39)
# 2020-01-15 19:21:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=WEE2> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=ULK3> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=ULK2> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=TNIK&Query_Pid=TNIK&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=NRK)
# 2020-01-15 19:21:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=STK36> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=PLK3> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=NEK9> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=PLK2> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=NEK8> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=NEK6> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=NEK4> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=NEK3> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=NEK11> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=NEK10> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=STRADA&Query_Pid=STRADA&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=ALS2CR2)
# 2020-01-15 19:21:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=MAP2K1&Query_Pid=MAP2K1&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MAP2K5)
# 2020-01-15 19:21:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=NEK5> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=CAMK1G&Query_Pid=CAMK1G&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=ULK3)
# 2020-01-15 19:21:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=MAP2K6&Query_Pid=MAP2K6&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MAP2K3)
# 2020-01-15 19:21:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=NEK1> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=ERN2> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CAMKK1> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=NEK2&Query_Pid=NEK2&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=NEK9)
# 2020-01-15 19:21:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=WEE1&Query_Pid=WEE1&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=WEE2)
# 2020-01-15 19:21:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=PLK4&Query_Pid=PLK4&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=ULK2)
# 2020-01-15 19:21:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=AURKC> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=NEK7&Query_Pid=NEK7&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=NEK6)
# 2020-01-15 19:21:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=PLK1&Query_Pid=PLK1&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=PLK3)
# 2020-01-15 19:21:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=SRPK3> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=SLK&Query_Pid=FYN&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=STK36)
# 2020-01-15 19:21:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=PRPF4B> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=AURKB> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=PFTK1> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=PCTK3> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=PCTK2> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=NLK> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=RAGE> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MAPK7> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MAPK15> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:21:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=CAMKK2&Query_Pid=CAMKK2&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CAMKK1)
# ...
# 2020-01-15 19:22:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=BUB1&Query_Pid=BUB1&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=BUB1)
# 2020-01-15 19:22:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=DYRK1A> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=SRPK1&Query_Pid=SRPK1&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=SRPK1)
# 2020-01-15 19:22:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CLK1> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CLK2> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=MAPK11&Query_Pid=MAPK11&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MAPK11)
# 2020-01-15 19:22:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=MAPK12&Query_Pid=MAPK12&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MAPK12)
# 2020-01-15 19:22:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CDK9> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CDK7> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CDK6> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=VRK1> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CDK5> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=EGFR&Query_Pid=EGFR&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=EGFR)
# 2020-01-15 19:22:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=MAPK9&Query_Pid=MAPK9&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MAPK9)
# 2020-01-15 19:22:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=CLK3&Query_Pid=CLK3&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CLK3)
# 2020-01-15 19:22:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=CSNK2A2&Query_Pid=CSNK2A2&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CSNK2A2)
# 2020-01-15 19:22:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CSNK1G3> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=MAPK10&Query_Pid=MAPK10&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MAPK10)
# 2020-01-15 19:22:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CSNK1G2> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=MAPK8&Query_Pid=MAPK8&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MAPK8)
# 2020-01-15 19:22:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=CSNK2A1&Query_Pid=CSNK2A1&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CSNK2A1)
# 2020-01-15 19:22:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=CLK2&Query_Pid=CLK2&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CLK2)
# 2020-01-15 19:22:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CDK2> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CSNK1G1> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=STK17B> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=CDK6&Query_Pid=CDK6&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CDK6)
# 2020-01-15 19:22:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=CDK7&Query_Pid=CDK7&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CDK7)
# 2020-01-15 19:22:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=VRK1&Query_Pid=VRK1&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=VRK1)
# 2020-01-15 19:22:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=PRKAA2> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CAMK2D> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=STK11> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CAMK2B> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CAMK2A> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CAMK1G> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CAMK1D> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=SGK1> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=ROCK1> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=RPS6KA5> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=RPS6KA1> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=PRKCI> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=PRKCQ> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=PRKCB> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=CSNK1G1&Query_Pid=CSNK1G1&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CSNK1G1)
# 2020-01-15 19:22:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=PRKCA> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=PRKACA> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=DMPK> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=GRK6> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=CAMK2A&Query_Pid=CAMK2A&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CAMK2A)
# 2020-01-15 19:22:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=CAMK2B&Query_Pid=CAMK2B&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CAMK2B)
# 2020-01-15 19:22:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=PDPK1> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=STK11&Query_Pid=STK11&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=STK11)
# 2020-01-15 19:22:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=CAMK2D&Query_Pid=CAMK2D&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=CAMK2D)
# 2020-01-15 19:22:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=AKT1> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=AKT2> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/browse.php)
# 2020-01-15 19:22:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=MAPK14&Query_Pid=MAPK14&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=MAPK14)
# 2020-01-15 19:22:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://gemdock.life.nctu.edu.tw/kidfammap/show_inhibitor.php?QueryType=Protein&QueryName=PDPK1&Query_Pid=PDPK1&Query_Cid=&Query_Family=> (referer: http://gemdock.life.nctu.edu.tw/kidfammap/ProcessQuery.php?ProteinQueryType=x&Query_ProteinName=PDPK1)
# 2020-01-15 19:22:17 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-01-15 19:22:17 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 186066,
#  'downloader/request_count': 490,
#  'downloader/request_method_count/GET': 490,
#  'downloader/response_bytes': 26036316,
#  'downloader/response_count': 490,
#  'downloader/response_status_count/200': 490,
#  'dupefilter/filtered': 191,
#  'elapsed_time_seconds': 35.829962,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 1, 15, 19, 22, 17, 914695),
#  'log_count/DEBUG': 491,
#  'log_count/INFO': 10,
#  'request_depth_max': 2,
#  'response_received_count': 490,
#  'scheduler/dequeued': 490,
#  'scheduler/dequeued/memory': 490,
#  'scheduler/enqueued': 490,
#  'scheduler/enqueued/memory': 490,
#  'start_time': datetime.datetime(2020, 1, 15, 19, 21, 42, 84733)}
# 2020-01-15 19:22:17 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# Clean up the data in "inhibs" and store in "inhibitors"

# %%
inhibitors = []

for i in inhibs: # for each kinase
    for j in i: # for each kinase-inhibitor relationship
        chemical = []
        inh = j.split("</td>") # Split row into individual fields
        for k in inh: # for each field, remove unnecessary characters
            field = k.replace("<tr>","") 
            field = field.replace("\r","")
            field = field.replace("\t","")
            field = field.replace("<td>","")
            field = field.replace("\n","")
            chemical.append(field) # Make a row of cleaned, separate fields
        inhibitors.append(chemical) # Add this row to "inhibitors"

# %% [markdown]
# Define column names, based on those on the KIDFamMap website

# %%
headers = ["Index","Kinase","Inhibitor","Partial_Img_URL",
           "Ki_nM","IC50_nM","Kd_nM","EC50_nM","POC","Source","Link","To_Remove"]

# %% [markdown]
# Save the inhibitors information in a Pandas data frame

# %%
inhibitors_df = pd.DataFrame(inhibitors, columns = headers)

# %% [markdown]
# Using information in the data frame, generate a column of URLs for the inhibitors' chemical structure images. Our web app can subsequently use these to display images.

# %%
IMG_URL = []

for n,i in enumerate(inhibitors_df.Partial_Img_URL):
    URL = 'http://gemdock.life.nctu.edu.tw/kidfammap/data/png/'
    URL += str(inhibitors_df.Source[n])+"/"
    URL += str(i)+".png"
    IMG_URL.append(URL)

IMG_URL = pd.Series(IMG_URL)
inhibitors_df = inhibitors_df.assign(IMG_URL = IMG_URL)

# %% [markdown]
# Make "kinase" and "inhibitor" entries uppercase.

# %%
uppercase_kinase = []
uppercase_inhib = []

for n,i in enumerate(inhibitors_df.Kinase):
    uppercase_kinase.append(str(i).upper())
    uppercase_inhib.append(inhibitors_df.Inhibitor[n].upper())

uppercase_kinase = pd.Series(uppercase_kinase)
uppercase_inhib = pd.Series(uppercase_inhib)

inhibitors_df = inhibitors_df.assign(Kinase = uppercase_kinase)
inhibitors_df = inhibitors_df.assign(Inhibitor = uppercase_inhib)

# %% [markdown]
# Translate kinase names using UniProt

# %%
kinase_list = list(inhibitors_df.Kinase.drop_duplicates())
len(kinase_list)
# Out:
# 148

# %%
# Create partial URL
url = "https://www.uniprot.org/uploadlists/"

# Define parameters
params = {
"from": "GENENAME", # Assume kinase names are in format "GENENAME"
"to": "ID", # Retrieve IDs in "ID" format
"format": "tab", # Produce tab-delimited output
"query": "", # The query protein ID will be defined during the loop
}

# Create an empty list to store the results in
results=[]

for i in kinase_list: 
    params["query"]=str(i) # Enter the kinase ID
    data = urllib.parse.urlencode(params) 
    data = data.encode("utf-8")
    req = urllib.request.Request(url, data) # Run query in Uniprot
    with urllib.request.urlopen(req) as f:
       response = f.read()
    line=response.decode("utf-8") 
    results.append(line) # Store results

# %%
# Split up the search results into a list of lists

results2=[]

for n,i in enumerate(results):
    results2.append(i.split())

# %%
# Make a dictionary of proteins

proteindict={}

for i in results2: # i = one kinase and all of its possible translations
    if(len(i)) > 2: # ignore empty lists
        humans = 0
        for e in range(3,len(i),2): # For every other item in the list (i.e. a potentially correct ID)
            if "_HUMAN" in str(i[e]): # check how many "human" options there are
                 humans += 1 
        if humans > 1: # If there are multiple "human" options
            for j in range(3,len(i),2):
                if str(i[j]) == str(i[2]) + "_HUMAN": # keep the one that equates to the original ID with
                    # suffix "_HUMAN"
                    proteindict[str(i[2])] = str(i[j])
        if humans == 1: # If there is only one "human" option, choose it
            for h in range(3,len(i),2):
                if "_HUMAN" in str(i[h]):
                    proteindict[str(i[2])] = str(i[h])

# %%
# Translate the kinases in the data frame and insert into new column

data = []

for n,i in enumerate(inhibitors_df.Kinase): # Iterate over original data frame's IDs
    if i in proteindict.keys():
        kinase = proteindict.get(i)
        data.append(kinase)
    else:
        data.append(str(i) + "_NOT_FOUND_IN_UNIPROT")

data = pd.Series(data)
inhibitors_df = inhibitors_df.assign(HUMAN_KINASE = data)

# %%
### UH OH! ###

inhibitors_df.HUMAN_KINASE.unique()
# Out:
# array(['ADRBK1_NOT_FOUND_IN_UNIPROT', 'DAPK3_HUMAN', 'DAPK2_HUMAN',
#        'DAPK1_HUMAN', 'PASK_HUMAN', 'MKNK2_HUMAN', 'MYLK4_HUMAN',
#        'MAPKAPK3_NOT_FOUND_IN_UNIPROT', 'CAMK2G_NOT_FOUND_IN_UNIPROT',
#        'CAMK4_NOT_FOUND_IN_UNIPROT', 'CASK_HUMAN',
#        'MAP3K9_NOT_FOUND_IN_UNIPROT', 'MAPK2_HUMAN', 'AVR2A_HUMAN',
#        'PIM1_HUMAN', 'CHEK1_NOT_FOUND_IN_UNIPROT', 'PIM2_HUMAN',
#        'BMPR1B_NOT_FOUND_IN_UNIPROT', 'KSR2_HUMAN',
#        'TNK2_NOT_FOUND_IN_UNIPROT', 'MERTK_HUMAN',
#        'CHEK2_NOT_FOUND_IN_UNIPROT', 'TEK_NOT_FOUND_IN_UNIPROT',
#        'RAF1_HUMAN', 'ITK_HUMAN', 'BMPR2_HUMAN',
#        'TGFBR1_NOT_FOUND_IN_UNIPROT', 'FYN_HUMAN', 'IRAK4_HUMAN',
#        'SRC_HUMAN', 'MET_HUMAN', 'ALK_HUMAN', 'INSR_HUMAN', 'FGFR1_HUMAN',
#        'IGF1R_HUMAN', 'FGFR2_HUMAN', 'KIT_HUMAN', 'CSK_HUMAN',
#        'FES_HUMAN', 'LYN_HUMAN', 'EPHA7_HUMAN', 'EPHA3_HUMAN',
#        'EPHB4_HUMAN', 'BTK_HUMAN', 'PAK1_HUMAN', 'HCK_HUMAN',
#        'OXSR1_HUMAN', 'TNIK_HUMAN', 'STRADA_NOT_FOUND_IN_UNIPROT',
#        'MAP2K1_NOT_FOUND_IN_UNIPROT', 'CAMK1G_NOT_FOUND_IN_UNIPROT',
#        'MAP2K6_NOT_FOUND_IN_UNIPROT', 'NEK2_HUMAN', 'WEE1_HUMAN',
#        'PLK4_HUMAN', 'NEK7_HUMAN', 'PLK1_HUMAN',
#        'CAMKK2_NOT_FOUND_IN_UNIPROT', 'ERN1_HUMAN', 'SRPK2_HUMAN',
#        'KDR_NOT_FOUND_IN_UNIPROT', 'PCTK1_NOT_FOUND_IN_UNIPROT',
#        'DYRK2_HUMAN', 'MAPK1_NOT_FOUND_IN_UNIPROT',
#        'MAPK3_NOT_FOUND_IN_UNIPROT', 'DYRK1A_NOT_FOUND_IN_UNIPROT',
#        'AURKA_HUMAN', 'CDK2_HUMAN', 'GSK3B_HUMAN', 'CDK9_HUMAN',
#        'CLK1_HUMAN', 'CDK5_HUMAN', 'CSNK1G3_NOT_FOUND_IN_UNIPROT',
#        'CSNK1G2_NOT_FOUND_IN_UNIPROT', 'CAMK1D_NOT_FOUND_IN_UNIPROT',
#        'STK17B_NOT_FOUND_IN_UNIPROT', 'PRKAA2_NOT_FOUND_IN_UNIPROT',
#        'RPS6KA1_NOT_FOUND_IN_UNIPROT', 'ROCK1_HUMAN', 'SGK1_HUMAN',
#        'RPS6KA5_NOT_FOUND_IN_UNIPROT', 'PRKACA_NOT_FOUND_IN_UNIPROT',
#        'PRKCI_NOT_FOUND_IN_UNIPROT', 'PRKCB_NOT_FOUND_IN_UNIPROT',
#        'AKT2_HUMAN', 'PRKCQ_NOT_FOUND_IN_UNIPROT', 'GRK6_HUMAN',
#        'AKT1_HUMAN', 'DMPK_HUMAN', 'PRKCA_NOT_FOUND_IN_UNIPROT',
#        'MAP3K7_NOT_FOUND_IN_UNIPROT', 'ILK_HUMAN',
#        'ACVRL1_NOT_FOUND_IN_UNIPROT', 'ACVR1_HUMAN', 'TYK2_HUMAN',
#        'ZAP70_HUMAN', 'SYK_NOT_FOUND_IN_UNIPROT',
#        'MST1R_NOT_FOUND_IN_UNIPROT', 'PTK2_NOT_FOUND_IN_UNIPROT',
#        'BRAF_HUMAN', 'RET_HUMAN', 'PTK2B_NOT_FOUND_IN_UNIPROT',
#        'JAK1_HUMAN', 'JAK3_HUMAN', 'ERBB4_HUMAN',
#        'FLT1_NOT_FOUND_IN_UNIPROT', 'ERBB3_HUMAN', 'EPHA2_HUMAN',
#        'LCK_HUMAN', 'ABL2_HUMAN', 'ERBB2_HUMAN', 'JAK2_HUMAN',
#        'CSF1R_HUMAN', 'STK24_HUMAN', 'STK25_HUMAN', 'STK10_HUMAN',
#        'PAK5_HUMAN', 'MST4_NOT_FOUND_IN_UNIPROT', 'PAK4_HUMAN',
#        'ABL1_HUMAN', 'TTK_HUMAN', 'MAP2K4_NOT_FOUND_IN_UNIPROT',
#        'MAP2K2_NOT_FOUND_IN_UNIPROT', 'GSG2_NOT_FOUND_IN_UNIPROT',
#        'STK16_HUMAN', 'EIF2AK2_NOT_FOUND_IN_UNIPROT', 'BUB1_HUMAN',
#        'SRPK1_HUMAN', 'MAPK11_NOT_FOUND_IN_UNIPROT',
#        'MAPK12_NOT_FOUND_IN_UNIPROT', 'EGFR_HUMAN',
#        'MAPK9_NOT_FOUND_IN_UNIPROT', 'CLK3_HUMAN',
#        'CSNK2A2_NOT_FOUND_IN_UNIPROT', 'MAPK10_NOT_FOUND_IN_UNIPROT',
#        'MAPK8_NOT_FOUND_IN_UNIPROT', 'CSNK2A1_NOT_FOUND_IN_UNIPROT',
#        'CLK2_HUMAN', 'CDK6_HUMAN', 'CDK7_HUMAN', 'VRK1_HUMAN',
#        'CSNK1G1_NOT_FOUND_IN_UNIPROT', 'CAMK2A_NOT_FOUND_IN_UNIPROT',
#        'CAMK2B_NOT_FOUND_IN_UNIPROT', 'STK11_HUMAN',
#        'CAMK2D_NOT_FOUND_IN_UNIPROT', 'MAPK14_NOT_FOUND_IN_UNIPROT',
#        'PDPK1_HUMAN'], dtype=object)

# %% [markdown]
# Make a temporary column combining the inhibitor and kinase names, to check for duplicates

# %%
unique = []

for n,i in enumerate(inhibitors_df.Inhibitor):
    uniq = str(i)+str(inhibitors_df.Kinase[n])
    unique.append(uniq)

unique = pd.Series(unique)
inhibitors_df = inhibitors_df.assign(UNIQUE = unique)

# %% [markdown]
# Drop any duplicate kinase-inhibitor pairs and reset the indices

# %%
inhibitors_df = inhibitors_df.drop_duplicates(subset="UNIQUE")
inhibitors_df = inhibitors_df.reset_index(drop=True)

# %% [markdown]
# Remove any columns not required for the web app

# %%
inhibitors_df = inhibitors_df.drop(["Index","To_Remove","Partial_Img_URL","Link","UNIQUE"], axis = 1)

# %% [markdown]
# Make data frame of kinase-inhibitor pairs

# %%
inhib_kin_df = inhibitors_df[['Kinase', 'Inhibitor']]

# %% [markdown]
# Make data frame of inhibitors

# %%
inhibitors_df = inhibitors_df.drop_duplicates(subset="Inhibitor")
inhibitors_df = inhibitors_df.drop(["Kinase"], axis = 1)
inhibitors_df = inhibitors_df.reset_index(drop=True)

# %% [markdown]
# Make a column of primary keys

# %%
prim_key = []

count = 1

for i in inhibitors_df.Inhibitor:
    key = "IN"+"{:07d}".format(count)
    prim_key.append(key)
    count += 1

prim_key = pd.Series(prim_key)

inhibitors_df = inhibitors_df.assign(ID_IN = prim_key)

# %%
prim_key = []

count = 1

for i in inhib_kin_df.Inhibitor:
    key = "KI"+"{:07d}".format(count)
    prim_key.append(key)
    count += 1

prim_key = pd.Series(prim_key)

inhib_kin_df = inhib_kin_df.assign(ID_KI = prim_key)

# %% [markdown]
# Write to csv

# %%
inhib_kin_df.to_csv("inhib_kin.csv", index = False)

# %%
inhibitors_df.to_csv("inhibitors.csv", index = False)
